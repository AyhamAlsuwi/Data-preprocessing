# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Diabetes.csv')

# %%
df
# Out:
#        Glucose Before fasting  Glucose Anytime   Age     Sex  Blood Pressure  \
# 0                       153.0            225.0  57.0  Female             0.0
# 1                       156.0            211.0  63.0    Male             0.0
# 2                        85.0            139.0  60.0    Male             0.0
# 3                       126.0            149.0  40.0    Male             1.0
# 4                       117.0            156.0  46.0    Male             1.0
# ...                       ...              ...   ...     ...             ...
# 15246                   116.0            265.0  54.0    Male             1.0
# 15247                    86.0            253.0  62.0  Female             1.0
# 15248                   148.0            136.0  28.0    Male             1.0
# 15249                   171.0            295.0  64.0  Female             0.0
# 15250                   179.0            178.0  39.0  Female             0.0
#
#        Family member with Diabetes past or present   BMI  Pregnancies  \
# 0                                              0.0  18.0          1.0
# 1                                              1.0  17.0          0.0
# 2                                              0.0  18.0          0.0
# 3                                              0.0  28.0          0.0
# 4                                              1.0  29.0          0.0
# ...                                            ...   ...          ...
# 15246                                          0.0  29.0          0.0
# 15247                                          0.0  40.0          0.0
# 15248                                          1.0  22.0          0.0
# 15249                                          0.0  28.0          0.0
# 15250                                          0.0  14.0          1.0
#
#        percentage of occuring diabetes
# 0                                69.50
# 1                                69.25
# 2                                14.50
# 3                                62.00
# 4                                52.25
# ...                                ...
# 15246                            62.25
# 15247                            55.00
# 15248                            45.50
# 15249                            67.00
# 15250                            43.50
#
# [15251 rows x 9 columns]

# %%
df.head(15)
# Out:
#     Glucose Before fasting  Glucose Anytime   Age     Sex  Blood Pressure  \
# 0                    153.0            225.0  57.0  Female             0.0
# 1                    156.0            211.0  63.0    Male             0.0
# 2                     85.0            139.0  60.0    Male             0.0
# 3                    126.0            149.0  40.0    Male             1.0
# 4                    117.0            156.0  46.0    Male             1.0
# 5                    151.0            286.0  38.0  Female             1.0
# 6                    106.0            277.0  56.0    Male             0.0
# 7                    139.0            234.0  39.0  Female             0.0
# 8                    115.0            271.0  42.0    Male             0.0
# 9                      NaN            191.0  59.0  Female             1.0
# 10                   163.0            181.0  53.0    Male             1.0
# 11                   113.0            203.0  32.0  Female             0.0
# 12                   112.0            129.0  24.0  Female             1.0
# 13                   151.0            138.0  47.0    Male             0.0
# 14                    92.0            216.0  65.0  Female             0.0
#
#     Family member with Diabetes past or present   BMI  Pregnancies  \
# 0                                           0.0  18.0          1.0
# 1                                           1.0  17.0          0.0
# 2                                           0.0  18.0          0.0
# 3                                           0.0  28.0          0.0
# 4                                           1.0  29.0          0.0
# 5                                           1.0  20.0          0.0
# 6                                           0.0  35.0          0.0
# 7                                           0.0  21.0          1.0
# 8                                           1.0  24.0          0.0
# 9                                           1.0  33.0          0.0
# 10                                          0.0  23.0          0.0
# 11                                          1.0  25.0          1.0
# 12                                          1.0  26.0          0.0
# 13                                          0.0  38.0          0.0
# 14                                          1.0  14.0          0.0
#
#     percentage of occuring diabetes
# 0                             69.50
# 1                             69.25
# 2                             14.50
# 3                             62.00
# 4                             52.25
# 5                             70.00
# 6                             53.75
# 7                             60.25
# 8                             56.00
# 9                             43.25
# 10                            60.75
# 11                            51.25
# 12                            31.50
# 13                            44.50
# 14                            43.50

# %%
df.tail(15)
# Out:
#        Glucose Before fasting  Glucose Anytime   Age     Sex  Blood Pressure  \
# 15236                   156.0            123.0  27.0    Male             0.0
# 15237                   145.0            236.0  44.0  Female             1.0
# 15238                    94.0            117.0  48.0  Female             1.0
# 15239                   143.0            107.0  31.0    Male             0.0
# 15240                   158.0            212.0  38.0    Male             0.0
# 15241                   122.0            295.0  45.0  Female             0.0
# 15242                   143.0            104.0  63.0  Female             0.0
# 15243                   116.0            112.0  59.0    Male             0.0
# 15244                    96.0            173.0  54.0  Female             1.0
# 15245                   120.0            101.0  60.0  Female             1.0
# 15246                   116.0            265.0  54.0    Male             1.0
# 15247                    86.0            253.0  62.0  Female             1.0
# 15248                   148.0            136.0  28.0    Male             1.0
# 15249                   171.0            295.0  64.0  Female             0.0
# 15250                   179.0            178.0  39.0  Female             0.0
#
#        Family member with Diabetes past or present   BMI  Pregnancies  \
# 15236                                          1.0  31.0          0.0
# 15237                                          1.0  15.0          1.0
# 15238                                          1.0  38.0          0.0
# 15239                                          1.0  28.0          0.0
# 15240                                          0.0  29.0          0.0
# 15241                                          1.0  18.0          0.0
# 15242                                          0.0  17.0          1.0
# 15243                                          0.0  25.0          0.0
# 15244                                          0.0  28.0          0.0
# 15245                                          0.0  40.0          0.0
# 15246                                          0.0  29.0          0.0
# 15247                                          0.0  40.0          0.0
# 15248                                          1.0  22.0          0.0
# 15249                                          0.0  28.0          0.0
# 15250                                          0.0  14.0          1.0
#
#        percentage of occuring diabetes
# 15236                            37.75
# 15237                            83.75
# 15238                            34.50
# 15239                            37.00
# 15240                            57.25
# 15241                            54.50
# 15242                            44.25
# 15243                            26.25
# 15244                            37.00
# 15245                            40.00
# 15246                            62.25
# 15247                            55.00
# 15248                            45.50
# 15249                            67.00
# 15250                            43.50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15251 entries, 0 to 15250
# Data columns (total 9 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Glucose Before fasting                       15231 non-null  float64
#  1   Glucose Anytime                              15233 non-null  float64
#  2   Age                                          15223 non-null  float64
#  3   Sex                                          15228 non-null  object
#  4   Blood Pressure                               15222 non-null  float64
#  5   Family member with Diabetes past or present  15224 non-null  float64
#  6   BMI                                          15238 non-null  float64
#  7   Pregnancies                                  15237 non-null  float64
#  8   percentage of occuring diabetes              15251 non-null  float64
# dtypes: float64(8), object(1)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#        Glucose Before fasting  Glucose Anytime           Age  Blood Pressure  \
# count            15231.000000     15233.000000  15223.000000    15222.000000
# mean               129.909855       190.399002     44.095382        0.499869
# std                 29.290305        64.141917     15.268833        0.500016
# min                 80.000000        80.000000     18.000000        0.000000
# 25%                104.000000       134.000000     31.000000        0.000000
# 50%                130.000000       191.000000     44.000000        0.000000
# 75%                155.000000       246.000000     57.000000        1.000000
# max                180.000000       300.000000     70.000000        1.000000
#
#        Family member with Diabetes past or present           BMI  \
# count                                 15224.000000  15238.000000
# mean                                      0.506043     26.953603
# std                                       0.499980      7.745629
# min                                       0.000000     14.000000
# 25%                                       0.000000     20.000000
# 50%                                       1.000000     27.000000
# 75%                                       1.000000     34.000000
# max                                       1.000000     40.000000
#
#         Pregnancies  percentage of occuring diabetes
# count  15237.000000                     15251.000000
# mean       0.249262                        51.622828
# std        0.432600                        16.924352
# min        0.000000                         3.500000
# 25%        0.000000                        40.000000
# 50%        0.000000                        52.250000
# 75%        0.000000                        64.500000
# max        1.000000                        90.000000

# %%
df.describe(include='O')
# Out:
#           Sex
# count   15228
# unique      2
# top      Male
# freq     7623

# %%
# 'Glucose Before fasting' is a wrong name for the records, the records indicates
df = df.rename(columns={'Glucose Before fasting':'Glucose after fasting','percentage of occuring diabetes':'Percentage of occuring diabetes'})

# %%
df
# Out:
#        Glucose after fasting  Glucose Anytime   Age     Sex  Blood Pressure  \
# 0                      153.0            225.0  57.0  Female             0.0
# 1                      156.0            211.0  63.0    Male             0.0
# 2                       85.0            139.0  60.0    Male             0.0
# 3                      126.0            149.0  40.0    Male             1.0
# 4                      117.0            156.0  46.0    Male             1.0
# ...                      ...              ...   ...     ...             ...
# 15246                  116.0            265.0  54.0    Male             1.0
# 15247                   86.0            253.0  62.0  Female             1.0
# 15248                  148.0            136.0  28.0    Male             1.0
# 15249                  171.0            295.0  64.0  Female             0.0
# 15250                  179.0            178.0  39.0  Female             0.0
#
#        Family member with Diabetes past or present   BMI  Pregnancies  \
# 0                                              0.0  18.0          1.0
# 1                                              1.0  17.0          0.0
# 2                                              0.0  18.0          0.0
# 3                                              0.0  28.0          0.0
# 4                                              1.0  29.0          0.0
# ...                                            ...   ...          ...
# 15246                                          0.0  29.0          0.0
# 15247                                          0.0  40.0          0.0
# 15248                                          1.0  22.0          0.0
# 15249                                          0.0  28.0          0.0
# 15250                                          0.0  14.0          1.0
#
#        Percentage of occuring diabetes
# 0                                69.50
# 1                                69.25
# 2                                14.50
# 3                                62.00
# 4                                52.25
# ...                                ...
# 15246                            62.25
# 15247                            55.00
# 15248                            45.50
# 15249                            67.00
# 15250                            43.50
#
# [15251 rows x 9 columns]

# %% [markdown]
# ### Handling missing values

# %%
df.isnull().sum()
# Out:
# Glucose after fasting                          20
# Glucose Anytime                                18
# Age                                            28
# Sex                                            23
# Blood Pressure                                 29
# Family member with Diabetes past or present    27
# BMI                                            13
# Pregnancies                                    14
# Percentage of occuring diabetes                 0
# dtype: int64

# %%
df['Glucose after fasting'] = df['Glucose after fasting'].fillna(df['Glucose after fasting'].median())

# %%
df['Glucose Anytime'] = df['Glucose Anytime'].fillna(df['Glucose Anytime'].median())

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df['Sex'] = df['Sex'].fillna(df['Sex'].mode()[0])

# %%
df['Blood Pressure'] = df['Blood Pressure'].fillna(df['Blood Pressure'].mode()[0])

# %%
df['Family member with Diabetes past or present'] =df['\
Family member with Diabetes past or present'].fillna(df['Family member with Diabetes past or present'].mode()[0])

# %%
df['BMI'] = df['BMI'].fillna(df['BMI'].median())

# %%
df['Pregnancies'] = df['Pregnancies'].fillna(df['Pregnancies'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Glucose after fasting                          0
# Glucose Anytime                                0
# Age                                            0
# Sex                                            0
# Blood Pressure                                 0
# Family member with Diabetes past or present    0
# BMI                                            0
# Pregnancies                                    0
# Percentage of occuring diabetes                0
# dtype: int64

# %%
# pregnant male!! must fix
df['Sex'][df['Pregnancies'] == 1].value_counts()
# Out:
# Sex
# Female    3790
# Male         8
# Name: count, dtype: int64

# %%
df.loc[df['Sex']=='Male' ,'Pregnancies'] = 0

# %%
df['Sex'][df['Pregnancies'] == 1].value_counts()
# Out:
# Sex
# Female    3790
# Name: count, dtype: int64

# %% [markdown]
# ### Outliers detection

# %%
#no outliers
plt.figure(figsize = (12,6))
plt.subplot(1,4,1)
sns.boxplot(y = df['Glucose after fasting'])
plt.subplot(1,4,2)
sns.boxplot(y = df['Glucose Anytime'])
plt.subplot(1,4,3)
sns.boxenplot(y=df['Age'])
plt.subplot(1,4,4)
sns.boxplot(y = df['BMI'])
plt.tight_layout();

# %% [markdown]
# ## Checking duplicates

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Temporarily handling categorical values for correlation matrix

# %%
temp_sex = df['Sex'].map({'Male':0 , 'Female':1})
temp_df = df.assign(Sex = temp_sex)
temp_df
# Out:
#        Glucose after fasting  Glucose Anytime   Age  Sex  Blood Pressure  \
# 0                      153.0            225.0  57.0    1             0.0
# 1                      156.0            211.0  63.0    0             0.0
# 2                       85.0            139.0  60.0    0             0.0
# 3                      126.0            149.0  40.0    0             1.0
# 4                      117.0            156.0  46.0    0             1.0
# ...                      ...              ...   ...  ...             ...
# 15246                  116.0            265.0  54.0    0             1.0
# 15247                   86.0            253.0  62.0    1             1.0
# 15248                  148.0            136.0  28.0    0             1.0
# 15249                  171.0            295.0  64.0    1             0.0
# 15250                  179.0            178.0  39.0    1             0.0
#
#        Family member with Diabetes past or present   BMI  Pregnancies  \
# 0                                              0.0  18.0          1.0
# 1                                              1.0  17.0          0.0
# 2                                              0.0  18.0          0.0
# 3                                              0.0  28.0          0.0
# 4                                              1.0  29.0          0.0
# ...                                            ...   ...          ...
# 15246                                          0.0  29.0          0.0
# 15247                                          0.0  40.0          0.0
# 15248                                          1.0  22.0          0.0
# 15249                                          0.0  28.0          0.0
# 15250                                          0.0  14.0          1.0
#
#        Percentage of occuring diabetes
# 0                                69.50
# 1                                69.25
# 2                                14.50
# 3                                62.00
# 4                                52.25
# ...                                ...
# 15246                            62.25
# 15247                            55.00
# 15248                            45.50
# 15249                            67.00
# 15250                            43.50
#
# [15250 rows x 9 columns]

# %% [markdown]
# ## EDA

# %%
plt.figure(figsize=(10,6))
corr_matrix = temp_df.corr()
sns.heatmap(corr_matrix , annot=True , cmap ='coolwarm')
plt.title('correlation matrix');

# %%
sns.histplot(x = df['Percentage of occuring diabetes']);

# %%
sns.histplot(x = df['Glucose after fasting']);

# %%
sns.histplot(x = df['Glucose Anytime']);

# %%
sns.histplot(x = df['Age']);

# %%
sns.histplot(x = df['BMI']);

# %%
''' Percentage of diabetes is increasing with Glucose record after fasting and there are three stages: below 100 ,
between 100 and 130, above 130 glucose record.'''
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sns.scatterplot(x = df['Glucose after fasting'] , y = df['Percentage of occuring diabetes'])
plt.title('Percentage of diabetes among glucose record after fasting')

plt.subplot(1,2,2)
sns.lineplot(x = df['Glucose after fasting'] , y = df['Percentage of occuring diabetes'])
plt.ylabel('Mean of percentage of occuring diabetes')
plt.title('Percentage of diabetes among glucose record after fasting')

plt.tight_layout();

# %%
''' Percentage of diabetes is increasing with Glucose record anytime and there are three stages: below 145 ,
between 145 and 205, above 205 glucose record.'''
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
sns.scatterplot(x = df['Glucose Anytime'] , y = df['Percentage of occuring diabetes'])
plt.title('Percentage of diabetes among glucose record anytime')

plt.subplot(1,2,2)
sns.lineplot(x = df['Glucose Anytime'] , y = df['Percentage of occuring diabetes'])
plt.ylabel('Mean of percentage of occuring diabetes')
plt.title('Percentage of diabetes among glucose record anytime')

plt.tight_layout();

# %%
# as age goes up percentage of diabetes increases, after 40 years old the the percentage is significantly increasing
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
sns.scatterplot(x = df['Age'] , y = df['Percentage of occuring diabetes'])
plt.title('Percentage of diabetes among age')

plt.subplot(1,2,2)
sns.lineplot(x = df['Age'] , y = df['Percentage of occuring diabetes'])
plt.ylabel('Mean of percentage of occuring diabetes')
plt.title('Percentage of diabetes among age')

plt.tight_layout();

# %%
# females are more likely to to have diabetes
plt.figure(figsize = (12,5))
plt.subplot(1,2,1)
sns.histplot(x = df['Percentage of occuring diabetes'] , hue = df['Sex'] ,bins = 20)
plt.subplot(1,2,2)
df.groupby(df['Sex'])['Percentage of occuring diabetes'].mean().plot(kind = 'bar')
plt.ylabel('Mean of Percentage of occuring diabetes');

# %%
# peaple with blood pressure has higher percentage of occuring diabetes
plt.figure(figsize = (12,5))
plt.subplot(1,2,1)
sns.histplot(x = df['Percentage of occuring diabetes'] , hue = df['Blood Pressure'],bins = 20)
plt.subplot(1,2,2)
df.groupby(df['Blood Pressure'])['Percentage of occuring diabetes'].mean().plot(kind = 'bar')
plt.ylabel('Mean of Percentage of occuring diabetes');

# %%
# peaple who have a relative with diabetes has higher percentage of occuring diabetes
plt.figure(figsize = (12,5))
plt.subplot(1,2,1)
sns.histplot(x = df['Percentage of occuring diabetes'] , hue = df['Family member with Diabetes past or present'],bins = 20)
plt.subplot(1,2,2)
df.groupby(df['Family member with Diabetes past or present'])['Percentage of occuring diabetes'].mean().plot(kind = 'bar')
plt.ylabel('Mean of Percentage of occuring diabetes');

# %%
# Pregnant females has higher percentage of occuring diabetes
plt.figure(figsize = (12,5))
plt.subplot(1,2,1)
sns.histplot(x = df['Percentage of occuring diabetes'] , hue = df.loc[df['Sex'] == 'Female' , 'Pregnancies'],bins = 20)
plt.subplot(1,2,2)
df.groupby(['Sex','Pregnancies'])['Percentage of occuring diabetes'].mean().plot(kind = 'bar')
plt.ylabel('Mean of Percentage of occuring diabetes');

# %%
# as BMI goes up percentage of diabetes increases.
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
sns.scatterplot(x = df['BMI'] , y = df['Percentage of occuring diabetes'])
plt.title('Percentage of diabetes among age')

plt.subplot(1,2,2)
sns.lineplot(x = df['BMI'] , y = df['Percentage of occuring diabetes'])
plt.ylabel('Mean of percentage of occuring diabetes')
plt.title('Percentage of diabetes among age')

plt.tight_layout();

# %%
df
# Out:
#        Glucose after fasting  Glucose Anytime   Age     Sex  Blood Pressure  \
# 0                      153.0            225.0  57.0  Female             0.0
# 1                      156.0            211.0  63.0    Male             0.0
# 2                       85.0            139.0  60.0    Male             0.0
# 3                      126.0            149.0  40.0    Male             1.0
# 4                      117.0            156.0  46.0    Male             1.0
# ...                      ...              ...   ...     ...             ...
# 15246                  116.0            265.0  54.0    Male             1.0
# 15247                   86.0            253.0  62.0  Female             1.0
# 15248                  148.0            136.0  28.0    Male             1.0
# 15249                  171.0            295.0  64.0  Female             0.0
# 15250                  179.0            178.0  39.0  Female             0.0
#
#        Family member with Diabetes past or present   BMI  Pregnancies  \
# 0                                              0.0  18.0          1.0
# 1                                              1.0  17.0          0.0
# 2                                              0.0  18.0          0.0
# 3                                              0.0  28.0          0.0
# 4                                              1.0  29.0          0.0
# ...                                            ...   ...          ...
# 15246                                          0.0  29.0          0.0
# 15247                                          0.0  40.0          0.0
# 15248                                          1.0  22.0          0.0
# 15249                                          0.0  28.0          0.0
# 15250                                          0.0  14.0          1.0
#
#        Percentage of occuring diabetes
# 0                                69.50
# 1                                69.25
# 2                                14.50
# 3                                62.00
# 4                                52.25
# ...                                ...
# 15246                            62.25
# 15247                            55.00
# 15248                            45.50
# 15249                            67.00
# 15250                            43.50
#
# [15250 rows x 9 columns]

# %%
df.groupby(df['Blood Pressure'])['Age'].mean()
# Out:
# Blood Pressure
# 0.0    44.031536
# 1.0    44.161935
# Name: Age, dtype: float64

# %%
df.groupby(['Sex','Blood Pressure'])['Percentage of occuring diabetes'].mean().plot(kind = 'bar')
plt.ylabel('Mean of Percentage of occuring diabetes');
